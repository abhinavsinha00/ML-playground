# %%
# %pip install matplotlib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_index=pd.read_csv("E:\ML-playground\ML\Regression\economic_index.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\prath\AppData\Local\Temp\ipykernel_29764\2746440042.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df_index=pd.read_csv("E:\ML-playground\ML\Regression\economic_index.csv")

# %%
df_index
# Out:
#     Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0            0  2017     12           2.75                5.3         1464
# 1            1  2017     11           2.50                5.3         1394
# 2            2  2017     10           2.50                5.3         1357
# 3            3  2017      9           2.50                5.3         1293
# 4            4  2017      8           2.50                5.4         1256
# 5            5  2017      7           2.50                5.6         1254
# 6            6  2017      6           2.50                5.5         1234
# 7            7  2017      5           2.25                5.5         1195
# 8            8  2017      4           2.25                5.5         1159
# 9            9  2017      3           2.25                5.6         1167
# 10          10  2017      2           2.00                5.7         1130
# ...

# %%
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
df_index.drop(["Unnamed: 0","year","month"], axis=1, inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
df_index.plot(kind = 'box', subplots = True, sharey = False, figsize = (10, 6))
plt.subplots_adjust()
plt.show()

# %%
import seaborn as sns 
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
plt.scatter(df_index['interest_rate'], df_index['unemployment_rate'], color='r')
plt.xlabel('intrest rate')
plt.ylabel('unemployment_rate')
# Out:
# Text(0, 0.5, 'unemployment_rate')

# %%
##independent and dependent feature 
X = df_index[['interest_rate', 'unemployment_rate']]
y = df_index['index_price']

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import seaborn as sns
sns.regplot(x='interest_rate', y='index_price', data=df_index)
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x='interest_rate', y='unemployment_rate', data=df_index)
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
# %pip install scikit-learn

from sklearn.linear_model import LinearRegression
regression = LinearRegression()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
##cross validation
from sklearn.model_selection import cross_val_score
validationn_score=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
np.mean(validationn_score)
# Out:
# np.float64(-5914.828180162386)

# %%
y_pred=regression.predict(X_test)

# %%
## performace metrix 
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse,mae,rmse)
# Out:
# 5793.762887712569 59.935781523235484 76.11677139574805

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
score
# Out:
# 0.8278978091457145

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 8     -45.227704
# 16    149.349481
# 0      57.486996
# 18     26.291104
# 11     80.090077
# 9      -1.169327
# Name: index_price, dtype: float64

# %%
sns.displot(residuals,kind='kde')

# %%
##scatter plot with respect to prediction and residuals 
plt.scatter(y_pred,residuals)

# %%
## OLS linear regression 
import statsmodels.api as sm
model=sm.OLS(y_train,X_train).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            index_price   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2880
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):                       0.754
# Time:                        16:08:54   Log-Likelihood:                         -150.85
# No. Observations:                  18   AIC:                                      305.7
# Df Residuals:                      16   BIC:                                      307.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
print(regression.coef_)
# Out:
# [  88.27275507 -116.25716066]
